# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bbs_x = np.array([21, 24, 22, 19, 27])
bbs_y = np.array([195, 201, 186, 198, 180])
rentner_x = np.array([72, 79, 83, 68, 89])
rentner_y = np.array([190, 165, 172, 178, 181])
andere_x = np.array([23, 59, 38, 54, 46])
andere_y = np.array([164, 187, 176, 191, 169])

# %%
30 / (90 - 15)
# Out:
# 0.4

# %%
fig, ax = plt.subplots()

plt.xlabel('Alter in Jahren')
plt.ylabel('Körpergröße in cm')
ax.set_ylim(160, 205)
ax.set_xlim(15, 95)
ax.set_axisbelow(True)
ax.grid()
ax.scatter(bbs_x, bbs_y, marker='^')
ax.scatter(rentner_x, rentner_y, marker='s')
ax.scatter(andere_x, andere_y)
ax.vlines([30, 65], ymin=160, ymax=205, colors=['red', 'red'], lw=[2, 2])
ax.hlines([175], xmin=15, xmax=95, colors=['red'], lw=[2])
ax.axhspan(ymin=175, ymax=205, xmax=(18/95), facecolor='b', alpha=0.2)
ax.axhspan(ymin=160, ymax=175, xmax=(18/95), facecolor='g', alpha=0.2)
ax.axhspan(ymin=160, ymax=205, xmin=(18/95), xmax=(60/95),facecolor='g', alpha=0.2)
ax.axhspan(ymin=160, ymax=205, xmin=(60/95), facecolor='orange', alpha=0.2)
ax.scatter(40, 195, c='r', marker='o')
ax.text(41, 196, s="P", c='r')
# Out:
# Text(41, 196, 'P')
